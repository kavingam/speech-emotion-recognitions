# %%
# Program to find all .wav file in a specific folder
import os

def find_wav_files(folder_path):
    # List to store .wav files
    wav_files = []

    # Walk through the folder
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            # Check if the file has a .wav extension
            if file.lower().endswith('.wav'):
                # Append the full path of the .wav file to the list
                wav_files.append(os.path.join(root, file))

    return wav_files

# Example usage
folder_path = 'C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad'  # Replace with your folder path
wav_files = find_wav_files(folder_path)

# Print the .wav files
for wav_file in wav_files:
    print(wav_file)
# Out:
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_back_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_bar_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_base_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_bath_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_bean_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_beg_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_bite_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_boat_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_bone_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_book_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_bought_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_burn_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_cab_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_calm_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_came_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_cause_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_chain_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_chair_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_chalk_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_chat_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_check_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_cheek_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_chief_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_choice_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_cool_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_dab_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_date_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_dead_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_death_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_deep_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_dime_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_dip_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_ditch_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_dodge_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_dog_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_doll_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_door_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_fail_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_fall_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_far_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_fat_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_fit_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_five_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_food_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_gap_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_gas_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_gaze_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_germ_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_get_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_gin_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_goal_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_good_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_goose_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_gun_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_half_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_hall_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_hash_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_hate_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_have_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_haze_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_hire_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_hit_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_hole_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_home_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_hurl_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_hush_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_jail_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_jar_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_join_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_judge_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_jug_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_juice_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_keen_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_keep_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_keg_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_kick_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_kill_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_king_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_kite_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_knock_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_late_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_laud_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_lean_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_learn_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_lease_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_lid_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_life_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_limb_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_live_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_loaf_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_long_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_lore_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_lose_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_lot_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_love_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_luck_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_make_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_match_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_merge_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_mess_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_met_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_mill_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_mob_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_mode_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_mood_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_moon_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_mop_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_mouse_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_nag_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_name_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_near_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_neat_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_nice_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_note_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_numb_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_pad_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_page_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_pain_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_pass_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_pearl_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_peg_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_perch_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_phone_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_pick_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_pike_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_pole_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_pool_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_puff_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_rag_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_raid_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_rain_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_raise_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_rat_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_reach_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_read_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_red_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_ring_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_ripe_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_road_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_room_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_rose_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_rot_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_rough_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_rush_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_said_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_sail_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_search_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_seize_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_sell_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_shack_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_shall_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_shawl_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_sheep_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_shirt_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_should_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_shout_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_size_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_soap_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_soup_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_sour_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_south_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_sub_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_such_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_sure_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_take_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_talk_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_tape_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_team_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_tell_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_thin_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_third_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_thought_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_thumb_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_time_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_tip_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_tire_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_ton_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_tool_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_tough_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_turn_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_vine_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_voice_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_void_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_vote_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_wag_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_walk_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_wash_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_week_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_wheat_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_when_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_which_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_whip_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_white_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_wife_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_wire_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_witch_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_yearn_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_yes_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_young_sad.wav
# C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad\YAF_youth_sad.wav

# %%
# Count the total number of .wav files in a specific folder
import os

def count_wav_files(folder_path):
    # Initialize a counter for .wav files
    wav_count = 0

    # Walk through the folder
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            # Check if the file has a .wav extension
            if file.lower().endswith('.wav'):
                wav_count += 1

    return wav_count

# Example usage
folder_path = 'C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad'  # Replace with your folder path
total_wav_files = count_wav_files(folder_path)

print(f"Total .wav files: {total_wav_files}")
# Out:
# Total .wav files: 200

# %%
# Search for a specific .wav file by name and deletes it if found 
import os

def search_and_delete_wav(folder_path, file_name):
    # Walk through the folder
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            # Check if the file matches the given name and is a .wav file
            if file.lower() == file_name.lower() and file.lower().endswith('.wav'):
                # Construct the full path to the file
                file_path = os.path.join(root, file)
                
                try:
                    # Delete the file
                    os.remove(file_path)
                    print(f"Deleted: {file_path}")
                    return True  # File found and deleted
                except Exception as e:
                    print(f"Error deleting file: {e}")
                    return False  # Error occurred during deletion

    print(f"File '{file_name}' not found.")
    return False  # File not found

# Example usage
folder_path = 'C:/Users/User/Downloads/Compressed/archive/Tess/YAF_sad'  # Replace with your folder path
file_name = 'example.wav'  # Replace with the file name you want to delete
deleted = search_and_delete_wav(folder_path, file_name)

if deleted:
    print("File deletion successful.")
else:
    print("File deletion failed or file not found.")
# Out:
# File 'example.wav' not found.
# File deletion failed or file not found.
